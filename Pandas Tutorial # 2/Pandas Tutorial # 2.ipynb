# %% [markdown]
# # How to Read Tabular Data in python pandas?

# %%
# Reading Tab separated Data

# %%
import pandas as pd

# %%
df = pd.read_csv("student.csv")

# %%
df.shape
# Out:
# (35, 5)

# %%
df.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   35 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  35 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.head(10)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78    male
# 9  10     Big John   Four    55  female

# %%
df.tail(10)
# Out:
#     id         name  class  mark  gender
# 25  26       Crelea  Seven    79    male
# 26  27     Big Nose  Three    81  female
# 27  28    Rojj Base  Seven    86  female
# 28  29  Tess Played  Seven    55    male
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.sample(5)
# Out:
#     id         name  class  mark  gender
# 6    7  My John Rob  Fifth    78    male
# 0    1     John Deo   Four    75  female
# 7    8       Asruid   Five    85    male
# 26  27     Big Nose  Three    81  female
# 19  20       Jackly   Nine    65  female

# %%
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
df.describe(include = "object")
# Out:
#             name  class gender
# count         35     35     35
# unique        35      8      2
# top     John Deo  Seven   male
# freq           1     10     18

# %% [markdown]
# # Adding/ Dropping Columns in Data Frame:

# %%
df = pd.read_csv("student.csv")
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df["new_mark"] = df["mark"] + 10

# %%
df.head()
# Out:
#    id        name  class  mark  gender  new_mark
# 0   1    John Deo   Four    75  female        85
# 1   2    Max Ruin  Three    85    male        95
# 2   3      Arnold  Three    55    male        65
# 3   4  Krish Star   Four    60  female        70
# 4   5   John Mike   Four    60  female        70

# %%
 df.drop(["name"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    id  class  mark  gender  new_mark
# 0   1   Four    75  female        85
# 1   2  Three    85    male        95
# 2   3  Three    55    male        65
# 3   4   Four    60  female        70
# 4   5   Four    60  female        70

# %% [markdown]
# # How to select A series from pandas Dataframe

# %%
df = pd.read_csv("student.csv")
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
mySeries = df["class"]

# %%
type(mySeries)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Different Formats of Tabular data:

# %%
import pandas as pd

# %%
df = pd.read_table("weather-parquet.tsv", sep = "\t")

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
df1 = pd.read_table("http://bit.ly/movieusers", sep = "|", header = None, skiprows = 1, names = user_cols)
df1
# Out:
#      user_id  age gender     occupation zip_code
# 0          2   53      F          other    94043
# 1          3   23      M         writer    32067
# 2          4   24      M     technician    43537
# 3          5   33      F          other    15213
# 4          6   42      M      executive    98101
# ..       ...  ...    ...            ...      ...
# 937      939   26      F        student    33319
# 938      940   32      M  administrator    02215
# 939      941   20      M        student    97229
# 940      942   48      F      librarian    78209
# 941      943   22      M        student    77841
#
# [942 rows x 5 columns]
